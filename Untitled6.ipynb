# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder
import matplotlib.pyplot as plt

df=pd.read_csv('audi.csv')
df
# Out:
#       model  year  price transmission  mileage fuelType  tax   mpg  engineSize
# 0        A1  2017  12500       Manual    15735   Petrol  150  55.4         1.4
# 1        A6  2016  16500    Automatic    36203   Diesel   20  64.2         2.0
# 2        A1  2016  11000       Manual    29946   Petrol   30  55.4         1.4
# 3        A4  2017  16800    Automatic    25952   Diesel  145  67.3         2.0
# 4        A3  2019  17300       Manual     1998   Petrol  145  49.6         1.0
# ...     ...   ...    ...          ...      ...      ...  ...   ...         ...
# 10663    A3  2020  16999       Manual     4018   Petrol  145  49.6         1.0
# 10664    A3  2020  16999       Manual     1978   Petrol  150  49.6         1.0
# 10665    A3  2020  17199       Manual      609   Petrol  150  49.6         1.0
# 10666    Q3  2017  19499    Automatic     8646   Petrol  150  47.9         1.4
# 10667    Q3  2016  15999       Manual    11855   Petrol  150  47.9         1.4
#
# ...

# %%
df.isnull().sum()
# Out:
# model           0
# year            0
# price           0
# transmission    0
# mileage         0
# fuelType        0
# tax             0
# mpg             0
# engineSize      0
# dtype: int64

# %%
import seaborn as sns
plt.figure(figsize = (15,8))
sns.lineplot( y ='price',x = 'year', data = df,palette = 'dark' )
# Out:
# <AxesSubplot:xlabel='year', ylabel='price'>

# %%
plt.figure(figsize = (15,8))
sns.lineplot( y ='price',x = 'engineSize', data = df,palette = 'dark' )
# Out:
# <AxesSubplot:xlabel='engineSize', ylabel='price'>

# %%
plt.figure(figsize = (15,8))
sns.lineplot( y ='price',x = 'tax', data = df,palette = 'dark' )
# Out:
# <AxesSubplot:xlabel='tax', ylabel='price'>

# %%
plt.figure(figsize = (15,8))
sns.lineplot( y ='price',x = 'mpg', data = df,palette = 'dark' )
# Out:
# <AxesSubplot:xlabel='mpg', ylabel='price'>

# %%
plt.figure(figsize = (15,8))
sns.lineplot( y ='price',x = 'mileage', data = df,palette = 'dark' )
# Out:
# <AxesSubplot:xlabel='mileage', ylabel='price'>

# %%
obj1 = df.select_dtypes(include = 'object').columns
obj1
# Out:
# Index(['model', 'transmission', 'fuelType'], dtype='object')

# %%
i = 1
plt.figure(figsize = (20,20))
for col in obj1:
    plt.subplot(3,2,i)
    sns.countplot(x = col, data = df, hue = 'fuelType')
    plt.title(col)
    i+=1

# %%
float1 = df.select_dtypes(exclude = 'object').columns
float1
# Out:
# Index(['year', 'price', 'mileage', 'tax', 'mpg', 'engineSize'], dtype='object')

# %%
i = 1
plt.figure(figsize = (20,20))
for col in float1:
    plt.subplot(3,3,i)
    sns.histplot(x = col, data = df)
    plt.title(col)
    i+=1

# %%
df['fuelType'].unique()
plt.figure(figsize = (15,15))
plt.subplot(2,1,1)
sns.boxplot(x = df['model'], y = df['price'],data = df, hue = 'fuelType')
plt.title("Audi Models with Price & Fuel Type")
plt.subplot(2,1,2)
sns.boxplot(x = df['model'], y = df['price'],data = df, hue = 'transmission')
plt.title("Audi Models with Price & TRANSMISSION Type")
# Out:
# Text(0.5, 1.0, 'Audi Models with Price & TRANSMISSION Type')

# %%
plt.figure(figsize = (15,8))
sns.lineplot( y ='price',x = 'year', data = df, hue = 'model',palette = 'dark' )
# Out:
# <AxesSubplot:xlabel='year', ylabel='price'>

# %%
sns.set(style="white")  
  
# Load the example mpg dataset  
mpg = sns.load_dataset("mpg")  
  
# Plot miles per gallon against horsepower with other semantics  
sns.relplot(x=df['mileage'], y=df['price'],hue=df['model'], size="weight",  
            sizes=(400, 40), alpha=.5, palette="muted",  
            height=6, data=mpg)

# %%
sns.set(style="white")  
  
# Load the example mpg dataset  
mpg = sns.load_dataset("mpg")  
  
# Plot miles per gallon against horsepower with other semantics  
sns.relplot(x=df['mileage'], y=df['price'],hue=df['fuelType'], size="weight",  
            sizes=(400, 40), alpha=.5, palette="muted",  
            height=6, data=mpg)

# %%
sns.set(style="white")  
  
# Load the example mpg dataset  
mpg = sns.load_dataset("mpg")  
  
# Plot miles per gallon against horsepower with other semantics  
sns.relplot(x=df['model'], y=df['price'],hue=df['fuelType'], size="weight",  
            sizes=(400, 40), alpha=.5, palette="muted",  
            height=6, data=mpg)

# %%
sns.set(style="white")  
  
# Load the example mpg dataset  
mpg = sns.load_dataset("mpg")  
  
# Plot miles per gallon against horsepower with other semantics  
sns.relplot(x=df['fuelType'], y=df['price'],hue=df['transmission'], size="weight",  
            sizes=(400, 40), alpha=.5, palette="muted",  
            height=6, data=mpg)

# %%
sns.set(style="white")  
  
# Load the example mpg dataset  
mpg = sns.load_dataset("mpg")  
  
# Plot miles per gallon against horsepower with other semantics  
sns.relplot(x=df['transmission'], y=df['price'],hue=df['fuelType'], size="weight",  
            sizes=(400, 40), alpha=.5, palette="muted",  
            height=6, data=mpg)

# %%
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import LabelEncoder
encoder=LabelEncoder()
df['model']=encoder.fit_transform(df['model'])
df['fuelType']=encoder.fit_transform(df['fuelType'])
df['transmission']=encoder.fit_transform(df['transmission'])


scaler = MinMaxScaler()
num_vars = ['year', 'price', 'mileage', 'tax','mpg','engineSize','model','fuelType','transmission']
df[num_vars] = scaler.fit_transform(df[num_vars])
df
# Out:
#        model      year     price  transmission   mileage  fuelType       tax  \
# 0       0.00  0.869565  0.076719           0.5  0.048712       1.0  0.258621
# 1       0.20  0.826087  0.104592           0.0  0.112081       0.0  0.034483
# 2       0.00  0.826087  0.066267           0.5  0.092709       1.0  0.051724
# 3       0.12  0.869565  0.106682           0.0  0.080344       0.0  0.250000
# 4       0.08  0.956522  0.110167           0.5  0.006183       1.0  0.250000
# ...      ...       ...       ...           ...       ...       ...       ...
# 10663   0.08  1.000000  0.108069           0.5  0.012437       1.0  0.250000
# 10664   0.08  1.000000  0.108069           0.5  0.006121       1.0  0.258621
# 10665   0.08  1.000000  0.109463           0.5  0.001882       1.0  0.258621
# 10666   0.36  0.869565  0.125490           0.0  0.026765       1.0  0.258621
# 10667   0.36  0.826087  0.101101           0.5  0.036700       1.0  0.258621
#
#             mpg  engineSize
# ...

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
from sklearn import metrics
x=df["year"].values[:,np.newaxis]
y=df["price"].values
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.30,random_state=0)
model=LinearRegression()   #build linear regression model
model.fit(x_train,y_train)  #fitting the training data
predicted=model.predict(x_test)
print("MSE", mean_squared_error(y_test,predicted))
print("R squared", metrics.r2_score(y_test,predicted))
# Out:
# MSE 0.0042302763253379855
# R squared 0.35773230897946906

# %%
plt.scatter(x,y,color="r")
plt.title("Linear Regression")
plt.ylabel("price")
plt.xlabel("mileage")
plt.plot(x,model.predict(x),color="k")
plt.show()

# %%
x=df[["engineSize","mileage","model"]]  #we have more than one input
y=df["price"].values
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=0) #splitting data with test size of 35%

model=LinearRegression() #build linear regression model
model.fit(x_train,y_train) #fitting the training data
predicted=model.predict(x_test) #testing our model’s performance

print("MSE", mean_squared_error(y_test,predicted))
print("R squared", metrics.r2_score(y_test,predicted))
# Out:
# MSE 0.0018732167345791287
# R squared 0.7155962177475412

# %%
from sklearn.preprocessing import PolynomialFeatures
x= df[["model","year", "mileage","engineSize"]]
y= df["price"].values

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.20, random_state=10)  #splitting data
lg=LinearRegression()
poly=PolynomialFeatures(degree=4)

x_train_fit = poly.fit_transform(x_train) #transforming our input data
lg.fit(x_train_fit, y_train)
x_test_ = poly.fit_transform(x_test)
predicted = lg.predict(x_test_)

print("MSE: ", metrics.mean_squared_error(y_test, predicted))
print("R squared: ", metrics.r2_score(y_test,predicted))
# Out:
# MSE:  0.0005993763875129705
# R squared:  0.9043425080777739

# %%
# Fitting Random Forest Regression to the dataset
# import the regressor
from sklearn.ensemble import RandomForestRegressor
x=df[["model","year", "mileage","engineSize"]]
y= df["price"].values
# create regressor object
regressor = RandomForestRegressor(n_estimators = 100, random_state = 0)

# fit the regressor with x and y data
regressor.fit(x, y)
# Out:
# RandomForestRegressor(random_state=0)

# %%
y_pred=regressor.predict(x_test)  #testing our model

# %%
x=metrics.r2_score(y_test,y_pred)
print(x)
# Out:
# 0.9830649811571232
