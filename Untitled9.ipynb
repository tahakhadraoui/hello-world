# %%
import pandas as pd
df=pd.read_csv('titanic-passengers.csv',delimiter=';')

# %%
df.head()
# Out:
#    PassengerId Survived  Pclass                                         Name  \
# 0          343       No       2                   Collander, Mr. Erik Gustaf
# 1           76       No       3                      Moen, Mr. Sigurd Hansen
# 2          641       No       3                       Jensen, Mr. Hans Peder
# 3          568       No       3  Palsson, Mrs. Nils (Alma Cornelia Berglund)
# 4          672       No       1                       Davidson, Mr. Thornton
#
#       Sex   Age  SibSp  Parch      Ticket     Fare  Cabin Embarked
# 0    male  28.0      0      0      248740  13.0000    NaN        S
# 1    male  25.0      0      0      348123   7.6500  F G73        S
# 2    male  20.0      0      0      350050   7.8542    NaN        S
# 3  female  29.0      0      4      349909  21.0750    NaN        S
# 4    male  31.0      1      0  F.C. 12750  52.0000    B71        S

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df['Age'].fillna(df['Age'].mean(),inplace=True)

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
nb=len(df['Cabin'])
print("nombre des elements",nb)
print(df['Cabin'].value_counts())
df['Cabin'].fillna('G6',inplace=True)
# Out:
# nombre des elements 891
# C23 C25 C27    4
# G6             4
# B96 B98        4
# F2             3
# E101           3
#               ..
# A14            1
# B73            1
# E77            1
# E17            1
# A32            1
# Name: Cabin, Length: 147, dtype: int64

# %%
df['Cabin'].fillna('G6',inplace= True)

# %%
df.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Cabin          0
# Embarked       2
# dtype: int64

# %%
print(df['Embarked'].value_counts())
# Out:
# S    644
# C    168
# Q     77
# Name: Embarked, dtype: int64

# %%
df['Embarked'].fillna('S',inplace= True)

# %%
df.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Cabin          0
# Embarked       0
# dtype: int64

# %%
df.head()
# Out:
#    PassengerId Survived  Pclass                                         Name  \
# 0          343       No       2                   Collander, Mr. Erik Gustaf
# 1           76       No       3                      Moen, Mr. Sigurd Hansen
# 2          641       No       3                       Jensen, Mr. Hans Peder
# 3          568       No       3  Palsson, Mrs. Nils (Alma Cornelia Berglund)
# 4          672       No       1                       Davidson, Mr. Thornton
#
#       Sex   Age  SibSp  Parch      Ticket     Fare  Cabin Embarked
# 0    male  28.0      0      0      248740  13.0000     G6        S
# 1    male  25.0      0      0      348123   7.6500  F G73        S
# 2    male  20.0      0      0      350050   7.8542     G6        S
# 3  female  29.0      0      4      349909  21.0750     G6        S
# 4    male  31.0      1      0  F.C. 12750  52.0000    B71        S

# %%
import seaborn as sns
grid = sns.FacetGrid(df, col="Survived", height=6, aspect=1)
grid.map(sns.barplot, "Sex", 'Age', alpha=.4, ci=None)
grid.add_legend()
# Out:
# C:\Users\lenovo i7\.android\tt\lib\site-packages\seaborn\axisgrid.py:643: UserWarning: Using the barplot function without specifying `order` is likely to produce an incorrect plot.
#   warnings.warn(warning)

# %%
#all female >= 30 are dying
#all male over 25 survived

# %%
import seaborn as sns
grid = sns.FacetGrid(df, col="Survived", height=6, aspect=1)
grid.map(sns.barplot, "Sex", 'Pclass', alpha=.4, ci=None)
grid.add_legend()
# Out:
# C:\Users\lenovo i7\.android\tt\lib\site-packages\seaborn\axisgrid.py:643: UserWarning: Using the barplot function without specifying `order` is likely to produce an incorrect plot.
#   warnings.warn(warning)

# %%
grid = sns.FacetGrid(df, col="Survived", height=6, aspect=1)
grid.map(sns.barplot, "Pclass", 'Fare', alpha=.4, ci=None)
grid.add_legend()
# Out:
# C:\Users\lenovo i7\.android\tt\lib\site-packages\seaborn\axisgrid.py:643: UserWarning: Using the barplot function without specifying `order` is likely to produce an incorrect plot.
#   warnings.warn(warning)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from sklearn import datasets, linear_model, preprocessing, svm
from sklearn.preprocessing import StandardScaler, Normalizer
import math
import matplotlib 
import seaborn as sns
def plot_correlation_map( df ):

    corr = df.corr()

    s , ax = plt.subplots( figsize =( 12 , 10 ) )

    cmap = sns.diverging_palette( 220 , 10 , as_cmap = True )

    s = sns.heatmap(

        corr, 

        cmap = cmap,

        square=True, 

        cbar_kws={ 'shrink' : .9 }, 

        ax=ax, 

        annot = True, 

        annot_kws = { 'fontsize' : 12 }

        )

# %%
    plot_correlation_map( df )

# %%
#the collération=1 This means the two variables moved either up or down in the same direction together.And this is a positive correlation

# %%
cleanup={"Survived":{"Yes":1, "No": 0}}
df.replace(cleanup, inplace=True)
df[["Pclass", "Survived"]].groupby(["Pclass"], as_index=True).mean()
# Out:
#         Survived
# Pclass
# 1       0.629630
# 2       0.472826
# 3       0.242363

# %%
df
# Out:
#      PassengerId  Survived  Pclass     Sex        Age  SibSp  Parch  \
# 0            343         0       2    male  28.000000      0      0
# 1             76         0       3    male  25.000000      0      0
# 2            641         0       3    male  20.000000      0      0
# 3            568         0       3  female  29.000000      0      4
# 4            672         0       1    male  31.000000      1      0
# ..           ...       ...     ...     ...        ...    ...    ...
# 886           10         1       2  female  14.000000      1      0
# 887           61         0       3    male  22.000000      0      0
# 888          535         0       3  female  30.000000      0      0
# 889          102         0       3    male  29.699118      0      0
# 890          428         1       2  female  19.000000      0      0
#
#          Ticket     Fare  Cabin Embarked
# 0        248740  13.0000     G6        S
# 1        348123   7.6500  F G73        S
# ...

# %%
data=pd.read_csv('titanic-passengers.csv',delimiter=';')

# %%
data
# Out:
#      PassengerId Survived  Pclass  \
# 0            343       No       2
# 1             76       No       3
# 2            641       No       3
# 3            568       No       3
# 4            672       No       1
# ..           ...      ...     ...
# 886           10      Yes       2
# 887           61       No       3
# 888          535       No       3
# 889          102       No       3
# 890          428      Yes       2
#
#                                                   Name     Sex   Age  SibSp  \
# 0                           Collander, Mr. Erik Gustaf    male  28.0      0
# 1                              Moen, Mr. Sigurd Hansen    male  25.0      0
# 2                               Jensen, Mr. Hans Peder    male  20.0      0
# 3          Palsson, Mrs. Nils (Alma Cornelia Berglund)  female  29.0      0
# 4                               Davidson, Mr. Thornton    male  31.0      1
# ..                                                 ...     ...   ...    ...
# ...

# %%
data=data.drop(['Fare'],axis=1)

# %%
l=list()
for i in data['Name']:
    x=i.find(',')
    y=i.find('.')
    l.append(i[x+2:y])
df['Tile']=l

# %%
df
# Out:
#      PassengerId  Survived  Pclass     Sex        Age  SibSp  Parch  \
# 0            343         0       2    male  28.000000      0      0
# 1             76         0       3    male  25.000000      0      0
# 2            641         0       3    male  20.000000      0      0
# 3            568         0       3  female  29.000000      0      4
# 4            672         0       1    male  31.000000      1      0
# ..           ...       ...     ...     ...        ...    ...    ...
# 886           10         1       2  female  14.000000      1      0
# 887           61         0       3    male  22.000000      0      0
# 888          535         0       3  female  30.000000      0      0
# 889          102         0       3    male  29.699118      0      0
# 890          428         1       2  female  19.000000      0      0
#
#          Ticket     Fare  Cabin Embarked  Tile
# 0        248740  13.0000     G6        S    Mr
# 1        348123   7.6500  F G73        S    Mr
# ...

# %%
import seaborn as sns
grid = sns.FacetGrid(df, col="Survived", height=6, aspect=1)
grid.map(sns.barplot, "Tile", 'Age', alpha=.4, ci=None)
grid.add_legend()
# Out:
# C:\Users\lenovo i7\.android\tt\lib\site-packages\seaborn\axisgrid.py:643: UserWarning: Using the barplot function without specifying `order` is likely to produce an incorrect plot.
#   warnings.warn(warning)

# %%
import seaborn as sns
grid = sns.FacetGrid(df, col="Survived", height=9, aspect=1)
grid.map(sns.barplot, "Tile", 'Fare', alpha=.10, ci=None)
grid.add_legend()
# Out:
# C:\Users\lenovo i7\.android\tt\lib\site-packages\seaborn\axisgrid.py:643: UserWarning: Using the barplot function without specifying `order` is likely to produce an incorrect plot.
#   warnings.warn(warning)

# %%
Title_Dictionary = {

                    "Capt":       "Officer",

                    "Col":        "Officer",

                    "Major":      "Officer",

                      "Dr":         "Officer",

                    "Rev":        "Officer",

                    "Jonkheer":   "Royalty",

                    "Don":        "Royalty",

                    "Sir" :       "Royalty",

                   "Lady" :      "Royalty",

                  "the Countess": "Royalty",

                    "Dona":       "Royalty",

                    "Mme":        "Miss",

                    "Mlle":       "Miss",

                    "Miss" :      "Miss",

                    "Ms":         "Mrs",

                    "Mr" :        "Mrs",

                    "Mrs" :       "Mrs",

                    "Master" :    "Master"

                    }

# %%
df.replace(Title_Dictionary,inplace= True)

# %%
df
# Out:
#      PassengerId  Survived  Pclass     Sex        Age  SibSp  Parch  \
# 0            343         0       2    male  28.000000      0      0
# 1             76         0       3    male  25.000000      0      0
# 2            641         0       3    male  20.000000      0      0
# 3            568         0       3  female  29.000000      0      4
# 4            672         0       1    male  31.000000      1      0
# ..           ...       ...     ...     ...        ...    ...    ...
# 886           10         1       2  female  14.000000      1      0
# 887           61         0       3    male  22.000000      0      0
# 888          535         0       3  female  30.000000      0      0
# 889          102         0       3    male  29.699118      0      0
# 890          428         1       2  female  19.000000      0      0
#
#          Ticket     Fare  Cabin Embarked  Tile
# 0        248740  13.0000     G6        S   Mrs
# 1        348123   7.6500  F G73        S   Mrs
# ...

# %%
import seaborn as sns
grid = sns.FacetGrid(df, col="Survived", height=9, aspect=1)
grid.map(sns.barplot, "Tile", 'Age', alpha=.10, ci=None)
grid.add_legend()
# Out:
# C:\Users\lenovo i7\.android\tt\lib\site-packages\seaborn\axisgrid.py:643: UserWarning: Using the barplot function without specifying `order` is likely to produce an incorrect plot.
#   warnings.warn(warning)

# %%
df['FamilySize']=df['SibSp']+df['Parch']
df
# Out:
#      PassengerId  Survived  Pclass     Sex        Age  SibSp  Parch  \
# 0            343         0       2    male  28.000000      0      0
# 1             76         0       3    male  25.000000      0      0
# 2            641         0       3    male  20.000000      0      0
# 3            568         0       3  female  29.000000      0      4
# 4            672         0       1    male  31.000000      1      0
# ..           ...       ...     ...     ...        ...    ...    ...
# 886           10         1       2  female  14.000000      1      0
# 887           61         0       3    male  22.000000      0      0
# 888          535         0       3  female  30.000000      0      0
# 889          102         0       3    male  29.699118      0      0
# 890          428         1       2  female  19.000000      0      0
#
#          Ticket     Fare  Cabin Embarked  Tile  FamilySize
# 0        248740  13.0000     G6        S   Mrs           0
# ...

# %%
df.drop(['SibSp','Parch'],axis=1)
# Out:
#      PassengerId  Survived  Pclass     Sex        Age      Ticket     Fare  \
# 0            343         0       2    male  28.000000      248740  13.0000
# 1             76         0       3    male  25.000000      348123   7.6500
# 2            641         0       3    male  20.000000      350050   7.8542
# 3            568         0       3  female  29.000000      349909  21.0750
# 4            672         0       1    male  31.000000  F.C. 12750  52.0000
# ..           ...       ...     ...     ...        ...         ...      ...
# 886           10         1       2  female  14.000000      237736  30.0708
# 887           61         0       3    male  22.000000        2669   7.2292
# 888          535         0       3  female  30.000000      315084   8.6625
# 889          102         0       3    male  29.699118      349215   7.8958
# 890          428         1       2  female  19.000000      250655  26.0000
#
#      Cabin Embarked  Tile  FamilySize
# ...

# %%
import seaborn as sns
grid = sns.FacetGrid(df, col="Survived", height=9, aspect=1)
grid.map(sns.barplot, "FamilySize", 'Sex', alpha=.10, ci=None)
grid.add_legend()
# Out:
# C:\Users\lenovo i7\.android\tt\lib\site-packages\seaborn\axisgrid.py:643: UserWarning: Using the barplot function without specifying `order` is likely to produce an incorrect plot.
#   warnings.warn(warning)

# %%
#female where FamilySize >0.5 survived
#male where family size > doesn't survive
