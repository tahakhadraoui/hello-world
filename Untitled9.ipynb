# %%
import pandas as pd
df=pd.read_csv('titanic-passengers.csv',delimiter=';')

# %%
df
# Out:
#      PassengerId Survived  Pclass  \
# 0            343       No       2
# 1             76       No       3
# 2            641       No       3
# 3            568       No       3
# 4            672       No       1
# ..           ...      ...     ...
# 886           10      Yes       2
# 887           61       No       3
# 888          535       No       3
# 889          102       No       3
# 890          428      Yes       2
#
#                                                   Name     Sex   Age  SibSp  \
# 0                           Collander, Mr. Erik Gustaf    male  28.0      0
# 1                              Moen, Mr. Sigurd Hansen    male  25.0      0
# 2                               Jensen, Mr. Hans Peder    male  20.0      0
# 3          Palsson, Mrs. Nils (Alma Cornelia Berglund)  female  29.0      0
# 4                               Davidson, Mr. Thornton    male  31.0      1
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df['Age'].fillna(df['Age'].median(),inplace=True)

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
nb=len(df['Cabin'])
print("nombre des elements",nb)
print(df['Cabin'].value_counts())
df['Cabin'].fillna('G6',inplace=True)
# Out:
# nombre des elements 891
# G6             691
# B96 B98          4
# C23 C25 C27      4
# F33              3
# E101             3
#               ...
# D15              1
# E34              1
# D50              1
# C87              1
# E17              1
# Name: Cabin, Length: 147, dtype: int64

# %%
df['Cabin'].fillna('G6',inplace= True)

# %%
df.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Cabin          0
# Embarked       2
# dtype: int64

# %%
print(df['Embarked'].value_counts())
# Out:
# S    644
# C    168
# Q     77
# Name: Embarked, dtype: int64

# %%
df['Embarked'].fillna('S',inplace= True)

# %%
df.isnull().sum().sum()
# Out:
# 0

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from sklearn import datasets, linear_model, preprocessing, svm
from sklearn.preprocessing import StandardScaler, Normalizer
import math
import matplotlib 
import seaborn as sns
def plot_correlation_map( df ):

    corr = df.corr()

    s , ax = plt.subplots( figsize =( 12 , 10 ) )

    cmap = sns.diverging_palette( 220 , 10 , as_cmap = True )

    s = sns.heatmap(

        corr, 

        cmap = cmap,

        square=True, 

        cbar_kws={ 'shrink' : .9 }, 

        ax=ax, 

        annot = True, 

        annot_kws = { 'fontsize' : 12 }

        )

# %%
plot_correlation_map( df )

# %%
#il ya ine forte correlation entre sibsp et passengerld we can use only SibSp

# %%
grid = sns.FacetGrid(df, col="Survived", height=6, aspect=1)
grid.map(sns.barplot, "Pclass", 'Fare', alpha=.4, ci=None)
grid.add_legend()
# Out:
# C:\Users\lenovo i7\.android\tt\lib\site-packages\seaborn\axisgrid.py:643: UserWarning: Using the barplot function without specifying `order` is likely to produce an incorrect plot.
#   warnings.warn(warning)

# %%
cleanup={"Survived":{"Yes":1, "No": 0}}
df.replace(cleanup, inplace=True)
df[["Pclass", "Survived"]].groupby(["Pclass"], as_index=True).mean()
# Out:
#         Survived
# Pclass
# 1       0.629630
# 2       0.472826
# 3       0.242363

# %%
data=pd.read_csv('titanic-passengers.csv',delimiter=';')
data
# Out:
#      PassengerId Survived  Pclass  \
# 0            343       No       2
# 1             76       No       3
# 2            641       No       3
# 3            568       No       3
# 4            672       No       1
# ..           ...      ...     ...
# 886           10      Yes       2
# 887           61       No       3
# 888          535       No       3
# 889          102       No       3
# 890          428      Yes       2
#
#                                                   Name     Sex   Age  SibSp  \
# 0                           Collander, Mr. Erik Gustaf    male  28.0      0
# 1                              Moen, Mr. Sigurd Hansen    male  25.0      0
# 2                               Jensen, Mr. Hans Peder    male  20.0      0
# 3          Palsson, Mrs. Nils (Alma Cornelia Berglund)  female  29.0      0
# 4                               Davidson, Mr. Thornton    male  31.0      1
# ..                                                 ...     ...   ...    ...
# ...

# %%
l=list()
for i in data['Name']:
    x=i.find(',')
    y=i.find('.')
    l.append(i[x+2:y])
df['Title']=l

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0            343         0       2
# 1             76         0       3
# 2            641         0       3
# 3            568         0       3
# 4            672         0       1
# ..           ...       ...     ...
# 886           10         1       2
# 887           61         0       3
# 888          535         0       3
# 889          102         0       3
# 890          428         1       2
#
#                                                   Name     Sex   Age  SibSp  \
# 0                           Collander, Mr. Erik Gustaf    male  28.0      0
# 1                              Moen, Mr. Sigurd Hansen    male  25.0      0
# 2                               Jensen, Mr. Hans Peder    male  20.0      0
# 3          Palsson, Mrs. Nils (Alma Cornelia Berglund)  female  29.0      0
# 4                               Davidson, Mr. Thornton    male  31.0      1
# ..                                                 ...     ...   ...    ...
# ...

# %%
import seaborn as sns
grid = sns.FacetGrid(df, col="Survived", height=6, aspect=1)
grid.map(sns.barplot, "Title", 'Age', alpha=.4, ci=None)
grid.add_legend()
# Out:
# C:\Users\lenovo i7\.android\tt\lib\site-packages\seaborn\axisgrid.py:643: UserWarning: Using the barplot function without specifying `order` is likely to produce an incorrect plot.
#   warnings.warn(warning)

# %%
Title_Dictionary = {

                    "Capt":       "Officer",

                    "Col":        "Officer",

                    "Major":      "Officer",

                      "Dr":         "Officer",

                    "Rev":        "Officer",

                    "Jonkheer":   "Royalty",

                    "Don":        "Royalty",

                    "Sir" :       "Royalty",

                   "Lady" :      "Royalty",

                  "the Countess": "Royalty",

                    "Dona":       "Royalty",

                    "Mme":        "Miss",

                    "Mlle":       "Miss",

                    "Miss" :      "Miss",

                    "Ms":         "Mrs",

                    "Mr" :        "Mrs",

                    "Mrs" :       "Mrs",

                    "Master" :    "Master"

                    }

# %%
df.replace(Title_Dictionary,inplace= True)

# %%
df['FamilySize']=df['SibSp']+df['Parch']

# %%
df.drop(['SibSp','Parch'],axis=1)
# Out:
#      PassengerId  Survived  Pclass  \
# 0            343         0       2
# 1             76         0       3
# 2            641         0       3
# 3            568         0       3
# 4            672         0       1
# ..           ...       ...     ...
# 886           10         1       2
# 887           61         0       3
# 888          535         0       3
# 889          102         0       3
# 890          428         1       2
#
#                                                   Name     Sex   Age  \
# 0                           Collander, Mr. Erik Gustaf    male  28.0
# 1                              Moen, Mr. Sigurd Hansen    male  25.0
# 2                               Jensen, Mr. Hans Peder    male  20.0
# 3          Palsson, Mrs. Nils (Alma Cornelia Berglund)  female  29.0
# 4                               Davidson, Mr. Thornton    male  31.0
# ..                                                 ...     ...   ...
# ...

# %%
import seaborn as sns
grid = sns.FacetGrid(df, col="Survived", height=9, aspect=1)
grid.map(sns.barplot, "FamilySize", 'Pclass', alpha=.10, ci=None)
grid.add_legend()
# Out:
# C:\Users\lenovo i7\.android\tt\lib\site-packages\seaborn\axisgrid.py:643: UserWarning: Using the barplot function without specifying `order` is likely to produce an incorrect plot.
#   warnings.warn(warning)

# %%
#female where FamilySize >0.5 survived
#male where family size > doesn't survive

# %%
data["Survived"]=data["Survived"].map({"Yes": 1, "No": 0})   #convert admitted variable into numerical
data.head()
# Out:
#    PassengerId  Survived  Pclass                                         Name  \
# 0          343       NaN       2                   Collander, Mr. Erik Gustaf
# 1           76       NaN       3                      Moen, Mr. Sigurd Hansen
# 2          641       NaN       3                       Jensen, Mr. Hans Peder
# 3          568       NaN       3  Palsson, Mrs. Nils (Alma Cornelia Berglund)
# 4          672       NaN       1                       Davidson, Mr. Thornton
#
#       Sex   Age  SibSp  Parch      Ticket     Fare  Cabin Embarked
# 0    male  28.0      0      0      248740  13.0000    NaN        S
# 1    male  25.0      0      0      348123   7.6500  F G73        S
# 2    male  20.0      0      0      350050   7.8542    NaN        S
# 3  female  29.0      0      4      349909  21.0750    NaN        S
# 4    male  31.0      1      0  F.C. 12750  52.0000    B71        S

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn import metrics

#features extraction
x = df[['FamilySize','Age','Pclass']]
y = df['Survived']

x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.25,random_state=0) 

logreg = LogisticRegression() 
logreg.fit(x_train, y_train) 
y_pred  = logreg.predict(x_test)

# %%
import seaborn as sns
sns.regplot(x=df['Age'],y=df['Survived'],data=data)
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Survived'>

# %%
confusion_matrix = pd.crosstab(y_test, y_pred, rownames=['Actual'], colnames=['Predicted'])
sns.heatmap(confusion_matrix, annot=True)
# Out:
# <AxesSubplot:xlabel='Predicted', ylabel='Actual'>

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.69      0.92      0.79       144
#            1       0.65      0.25      0.36        79
#
#     accuracy                           0.69       223
#    macro avg       0.67      0.59      0.58       223
# weighted avg       0.68      0.69      0.64       223

# %%
#AUC - ROC curve is a performance measurement for the classification problems at various threshold settings. ROC is a probability curve and AUC represents the degree or measure of separability. It tells how much the model is capable of distinguishing between classes

# %%
from sklearn.metrics import roc_curve
y_pred  = logreg.predict(x_test).ravel()
fpr,tpr,thresholds=roc_curve(y_test,y_pred)
plt.plot([0,1],[0,1],'y--')
plt.plot(fpr,tpr,marker='.')
plt.xlabel('False positive rate')
plt.ylabel('True positive rate')
plt.title('roc curve')
plt.show()

# %%
from sklearn.metrics import auc
aux_value=auc(fpr,tpr)
print(aux_value)
# Out:
# 0.5883878340365682
